# %% [markdown]
# #ColabNAS code

# %%
# !pip install tensorflow==2.15.0
# Out:
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15.0)
#   Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.70.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)
# Downloading tensorflow-2.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 3.1 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 59.0 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.9 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 76.4 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 28.6 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
#     Uninstalling keras-3.8.0:
#       Successfully uninstalled keras-3.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.18.0
#     Uninstalling tensorflow-2.18.0:
#       Successfully uninstalled tensorflow-2.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.15.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.15.0 which is incompatible.
# tensorstore 0.1.71 requires ml_dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1

# %%
import tensorflow as tf
import numpy as np
import subprocess
import datetime
import glob
import re
import os
import shutil
from sklearn.model_selection import train_test_split
import cv2
from tensorflow.keras.utils import to_categorical

# Global variables to save the best model's information
global_base_models = []
global_exits = []
best_model = None
best_k = 0
best_c = 0

final_path = "final_architecture/"

class ColabNAS :
    architecture_name = 'resulting_architecture'
    def __init__(self, max_RAM, max_Flash, max_MACC, path_to_training_set, val_split, cache=False, input_shape=[320,320], save_path='./') :
        self.learning_rate = 1e-3
        self.batch_size = 128
        self.epochs = 2 #minimum 2, 100 initial

        self.max_MACC = max_MACC
        self.max_Flash = max_Flash
        self.max_RAM = max_RAM
        self.path_to_training_set = path_to_training_set
        # self.num_classes = len(next(os.walk(path_to_training_set))[1])
        self.num_classes = 2 # Dense 10
        self.val_split = val_split
        self.cache = cache
        self.input_shape = input_shape
        self.save_path = save_path

        self.path_to_trained_models = f"{self.save_path}/trained_models"
        os.makedirs(self.path_to_trained_models)

        self.base_models = []
        self.exits = []

        self.model = None

        # For dataset
        self.train_images = None
        self.train_labels = None

        self.test_images = None
        self.test_labels = None

        self.load_training_set()

    # # k number of kernels of the first convolutional layer
    # # c number of cells added upon the first convolutional layer
    # # pre-processing pipeline not included in MACC computation
    # def Model(self, k, c):
    #     kernel_size = (3, 3)
    #     pool_size = (2, 2)
    #     pool_strides = (2, 2)

    #     # Reset
    #     self.base_models = [] # Will hold base sub-models
    #     self.exits = []  # Will hold exit heads
    #     self.final_base_model = [] # will hold final base model

    #     # Preprocessing pipeline
    #     preprocessing = tf.keras.Sequential([
    #         tf.keras.layers.RandomFlip('horizontal'),
    #         tf.keras.layers.RandomRotation(0.2, fill_mode='constant', interpolation='bilinear'),
    #         tf.keras.layers.Rescaling(1. / 255),
    #         tf.keras.layers.BatchNormalization(),
    #     ], name="preprocessing")

    #     n = k  # Number of filters for the first convolutional layer
    #     multiplier = 2
    #     number_of_cells_limited = False
    #     number_of_mac = 0

    #     # ----------- Start building the first base model ----------------
    #     base_model_layers = [
    #         tf.keras.layers.InputLayer(input_shape=self.input_shape),
    #         preprocessing,
    #         tf.keras.layers.Conv2D(n, kernel_size, activation='relu', padding='same'),
    #     ]
    #     c_in = self.input_shape[2]
    #     number_of_mac += c_in * kernel_size[0] * kernel_size[1] * (self.input_shape[0] ** 2) * n

    #     # FIXME: Doesn't run when c = 0 --> which is right bc it shouldn't run cell-based search when c=0
    #     # --------------- Now, use cell-base method to add exits ---------------
    #     for i in range(1, c + 1):
    #         if self.input_shape[0] <= 1 or self.input_shape[1] <= 1:  # Stop if spatial dimensions are too small
    #             number_of_cells_limited = True
    #             break

    #         # Add layers to the current base model
    #         base_model_layers.append(tf.keras.layers.MaxPooling2D(pool_size=pool_size, strides=pool_strides, padding='valid'))
    #         n = int(np.ceil(n * multiplier))    # Determines the new filter n
    #         multiplier -= 2 ** -i
    #         base_model_layers.append(tf.keras.layers.Conv2D(n, kernel_size, activation='relu', padding='same'))
    #         c_in = n
    #         number_of_mac += c_in * kernel_size[0] * kernel_size[1] * (self.input_shape[0] // (2 ** i)) ** 2 * n    # TODO: check if MACC is accurate later

    #         # Add an early exit (but check with this if statement to prevent adding a last exit bc we're going to add final exit at the end manually)
    #         if i < c:
    #             print(f"---exit_{i} being added---")
    #             exit_layers = [
    #                 tf.keras.layers.GlobalAveragePooling2D(),
    #                 tf.keras.layers.Dense(n, activation='relu'),
    #                 tf.keras.layers.Dense(self.num_classes, activation='softmax'),
    #             ]
    #             self.exits.append(tf.keras.Sequential(exit_layers, name=f"exit_{i}"))
    #         else:
    #             # Append more layers to make final base model
    #             base_model_layers.append(tf.keras.layers.GlobalAveragePooling2D())
    #             base_model_layers.append(tf.keras.layers.Dense(n, activation='relu'))
    #             base_model_layers.append(tf.keras.layers.Dense(self.num_classes, activation='softmax'))

    #             self.base_models.append(tf.keras.Sequential(base_model_layers, name=f"final_base_model"))
    #             break

    #         # Save the current base model as a separate chunk
    #         self.base_models.append(tf.keras.Sequential(base_model_layers, name=f"base_model_{i}"))

    #         base_model_layers = [] # reset

    #     # ---------------- Final base model ----------------
    #     # final_base_layers = [
    #     #     tf.keras.layers.GlobalAveragePooling2D(),
    #     #     tf.keras.layers.Dense(n, activation='relu'),
    #     #     tf.keras.layers.Dense(self.num_classes, activation='softmax'),
    #     # ]
    #     # self.final_base_model = tf.keras.Sequential(final_base_layers, name="final_base_model")

    #     # TODO:
    #     # ----------- Connect each base models & exits together -------------
    #     # NOTE: base_model has total c number of base models (ex. if c=3, basemodel1, basemodel2, final_base_model)
    #     # NOTE: exits has c - 1 exits (bc of final exit) (ex. if c=3, exit1, exit2)
    #     z_list = []
    #     out_list = []
    #     image_input = tf.keras.layers.Input(shape=self.input_shape, name='Input')
    #     print("--- base models ---")
    #     print(self.base_models)

    #     print("--- exits ---")
    #     print(self.exits)

    #     input_for_connection = image_input
    #     for idx, base_model in enumerate(self.base_models[:-1]):
    #         z_input = base_model(input_for_connection)          # NOTE: z_input = input that goes into another base_model
    #         z_list.append(z_input)

    #         # NOTE: output of final_base_model is final exit, and since this final exit is NOT part of self.exits, check
    #         if idx < len(self.exits):
    #             out1 = self.exits[idx](z_input)
    #             out_list.append(out1)

    #         # update input for next base model & exit
    #         input_for_connection = z_input

    #     final_out = []
    #     # Check if it's empty before adding to the fnal base model
    #     if len(z_list) != 0:
    #         final_out = [self.base_models[-1](z_list[-1])]  # last z goes in as an input to final base model
    #     else:
    #         # FIXME: when c=0. cannot be list error -> bc one of these is empty list []
    #         final_out = list(self.base_models[-1](self.base_models[0](image_input)))

    #     print("--- out_list ---")
    #     print(out_list)

    #     print("--- final_list ---")
    #     print(final_out)

    #     model = tf.keras.Model(
    #         inputs=image_input,
    #         outputs=out_list + final_out
    #     )
    #     model.summary()

    #     # ---------- Compile the multi-exit model --------------
    #     # NOTE: Since there are multiple exits, you need multiple metrics for each exit (including final exit) w/ different metric names
    #     metrics_list = []
    #     for i in range(1, len(self.exits) + 1):
    #         metrics_list.append([tf.keras.metrics.CategoricalAccuracy(name=f'accuracy_exit_{i}')])
    #     metrics_list.append([tf.keras.metrics.CategoricalAccuracy(name=f'accuracy_final_exit')])   # 1 more for final_exit (again, final is not in self.exits)
    #     opt = tf.keras.optimizers.Adam(learning_rate=self.learning_rate, clipvalue=1.0)  # NOTE: clipvalue for gradient clipping

    #     model.compile(optimizer=opt,
    #               loss=['categorical_crossentropy'] * (len(self.exits) + 1),
    #               metrics=metrics_list)

    #     # TODO: check if number_of_mac is accurate
    #     # Return base models, exits, and additional information
    #     return model, number_of_mac, number_of_cells_limited

        ###############################################################
        ###############################################################


    # k number of kernels of the first convolutional layer
    # c number of cells added upon the first convolutional layer
    # pre-processing pipeline not included in MACC computation
    def Model(self, k, c):
        kernel_size = (3, 3)
        pool_size = (2, 2)
        pool_strides = (2, 2)

        # Reset
        self.base_models = [] # Will hold base sub-models
        self.exits = []  # Will hold exit heads

        # Preprocessing pipeline
        preprocessing = tf.keras.Sequential([
            tf.keras.layers.RandomFlip('horizontal'),
            tf.keras.layers.RandomRotation(0.2, fill_mode='constant', interpolation='bilinear'),
            tf.keras.layers.Rescaling(1. / 255),
            tf.keras.layers.BatchNormalization(),
        ], name="preprocessing")


        # self_input_shape = [28,28]

        n = k  # Number of filters for the first convolutional layer
        number_of_cells_limited = False
        number_of_mac = 0

        # ----------- Start building the first base model ----------------
        # base_model_layers = [
        #     tf.keras.layers.InputLayer(input_shape=self.input_shape),
        #     tf.keras.layers.Reshape(target_shape=(28, 28, 1)),
        # ]
        base_model_layers = [
            tf.keras.layers.InputLayer(input_shape=self.input_shape),
            preprocessing
            # tf.keras.layers.Conv2D(n, kernel_size, activation='relu', padding='same'),
        ]


        # FIXME: Doesn't run when c = 0 --> which is right bc it shouldn't run cell-based search when c=0
        # --------------- Now, use cell-base method to add exits ---------------
        for i in range(1, c + 1):
            if self.input_shape[0] <= 1 or self.input_shape[1] <= 1:  # Stop if spatial dimensions are too small
                number_of_cells_limited = True
                break

            # Add layers to the current base model
            base_model_layers.append(tf.keras.layers.Conv2D(n, kernel_size, activation='relu', padding='same'))
            # base_model_layers.append(tf.keras.layers.MaxPooling2D(pool_size=pool_size, strides=pool_strides, padding='valid'))

            if i == c:  # Add final exit (main exit) at the end of the run
                # Append more layers to make final base model
                # base_model_layers.append(tf.keras.layers.Conv2D(n, kernel_size, activation='relu', padding='same'))
                # base_model_layers.append(tf.keras.layers.GlobalAveragePooling2D())
                base_model_layers.append(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))  # <- add this bc globalavgpooling is not in tflite (averagepool is there tho)
                base_model_layers.append(tf.keras.layers.Flatten())
                base_model_layers.append(tf.keras.layers.Dense(self.num_classes, activation='softmax'))

                self.base_models.append(tf.keras.Sequential(base_model_layers, name=f"final_base_model"))
                break
            # Add an early exit (but check with this if statement to prevent adding a last exit bc we're going to add final exit at the end manually)
            # for every 2 cells (c)
            elif i < c:
                print(f"---exit_{i} being added---")
                exit_layers = [
                    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
                    #tf.keras.layers.Conv2D(n, kernel_size, activation='relu', padding='same'),
                    #tf.keras.layers.GlobalAveragePooling2D(),
                    tf.keras.layers.Flatten(),
                    tf.keras.layers.Dense(self.num_classes, activation='softmax'),
                ]
                self.exits.append(tf.keras.Sequential(exit_layers, name=f"exit_{i}"))

            # Save the current base model as a separate chunk
            self.base_models.append(tf.keras.Sequential(base_model_layers, name=f"base_model_{i}"))

            base_model_layers = [] # reset
            n = n * 2

        # TODO:
        # ----------- Connect each base models & exits together -------------
        # NOTE: base_model has total c number of base models (ex. if c=3, basemodel1, basemodel2, final_base_model)
        # NOTE: exits has c - 1 exits (bc of final exit) (ex. if c=3, exit1, exit2)
        z_list = []
        out_list = []
        image_input = tf.keras.layers.Input(shape=self.input_shape, name='input')

        input_for_connection = image_input
        for idx, base_model in enumerate(self.base_models[:-1]):
            z_input = base_model(input_for_connection)          # NOTE: z_input = input that goes into another base_model
            z_list.append(z_input)

            # NOTE: output of final_base_model is final exit, and since this final exit is NOT part of self.exits, check
            if len(self.exits) != 0:
                out1 = self.exits[idx](z_input)
                out_list.append(out1)

            # update input for next base model & exit
            input_for_connection = z_input

        final_out = []
        # Check if it's empty before adding to the fnal base model
        if len(z_list) != 0:
            final_out = [self.base_models[-1](z_list[-1])]  # last z goes in as an input to final base model
        else:
            # FIXME: when c=0. cannot be list error -> bc one of these is empty list []
            final_out = [self.base_models[-1](image_input)]

        model = tf.keras.Model(
            inputs=image_input,
            outputs=out_list + final_out
        )
        model.summary()

        # ---------- Compile the multi-exit model --------------
        # NOTE: Since there are multiple exits, you need multiple metrics for each exit (including final exit) w/ different metric names
        metrics_list = []
        for i in range(1, len(self.exits) + 1):
            metrics_list.append([tf.keras.metrics.CategoricalAccuracy(name=f'accuracy_exit_{i}')])
        metrics_list.append([tf.keras.metrics.CategoricalAccuracy(name=f'accuracy_final_exit')])   # 1 more for final_exit (again, final is not in self.exits)

        opt = tf.keras.optimizers.Adam(learning_rate=self.learning_rate, clipvalue=1.0)  # NOTE: clipvalue for gradient clipping
        model.compile(optimizer=opt,
                  loss=['categorical_crossentropy'] * (len(self.exits) + 1),
                  metrics=metrics_list)

        # model.compile(optimizer='adam',
        #         loss=[tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)] * (len(self.exits) + 1),
        #         loss_weights=[0.33] * (len(self.exits) + 1),
        #         metrics=['accuracy']
        #         )

        return model, number_of_mac, number_of_cells_limited


    def dataset_to_numpy(self, dataset):
        """
        Convert a tf.data.Dataset into NumPy arrays for images and labels.

        Args:
            dataset (tf.data.Dataset): The dataset to convert.

        Returns:
            tuple: A tuple (images, labels) where both are NumPy arrays.
        """
        images, labels = [], []
        for image_batch, label_batch in dataset:
            images.append(image_batch.numpy())
            labels.append(label_batch.numpy())

        # Concatenate all batches into single arrays
        images = np.concatenate(images, axis=0)
        labels = np.concatenate(labels, axis=0)
        return images, labels


    def load_training_set(self):
        """
        Load the training set
        """
        if 3 == self.input_shape[2] :
            color_mode = 'rgb'
        elif 1 == self.input_shape[2] :
            color_mode = 'grayscale'

        train_ds = tf.keras.utils.image_dataset_from_directory(
            directory= self.path_to_training_set,
            labels='inferred',
            label_mode='categorical',
            color_mode=color_mode,
            batch_size=self.batch_size,
            image_size=self.input_shape[0:2],
            shuffle=True,
            seed=11,
            validation_split=self.val_split,
            subset='training'
        )

        validation_ds = tf.keras.utils.image_dataset_from_directory(
            directory= self.path_to_training_set,
            labels='inferred',
            label_mode='categorical',
            color_mode=color_mode,
            batch_size=self.batch_size,
            image_size=self.input_shape[0:2],
            shuffle=True,
            seed=11,
            validation_split=self.val_split,
            subset='validation'
        )

        if self.cache :
            self.train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
            self.validation_ds = validation_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
        else :
            self.train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
            self.validation_ds = validation_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

        # Load and preprocess your dataset
        # def read_and_preprocess_image(image_path):
        #     image = cv2.imread(image_path, 0) # 0: Gray Scale
        #     if image is None:
        #       print("Wrong Path")
        #       return None
        #     else:
        #       image = cv2.resize(image, self.input_shape)
        #     return image

        # data = []
        # labels = []

        # for class_name in os.listdir(main_dir):
        #     class_dir = os.path.join(main_dir, class_name)
        #     for image_file in os.listdir(class_dir):
        #         image_path = os.path.join(class_dir, image_file)
        #         image = read_and_preprocess_image(image_path)
        #         if image is not None:
        #           data.append(image)
        #           labels.append(int(class_name))  # Assuming class names are 0 and 1

        # # Convert labels to one-hot encoding
        # labels = to_categorical(labels, num_classes=2)

        # train_images, test_images, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42)

        # mnist = tf.keras.datasets.mnist
        # (train_images, train_labels), (test_images, test_labels) = mnist.load_data()

        # self.train_images = train_images.astype(np.float32) / 255.0
        # self.test_images = test_images.astype(np.float32) / 255.0

        # self.train_labels = train_labels
        # self.test_labels = test_labels

        # Convert to NumPy arrays and normalize
        # self.train_images = np.array(train_images, dtype=np.float32) / 255.0
        # self.test_images = np.array(test_images, dtype=np.float32) / 255.0

        # self.train_labels = np.array(train_labels)  # Ensure labels are also NumPy arrays
        # self.test_labels = np.array(test_labels)


    def quantize_model_uint8(self) :

        # def representative_dataset():
        #     for data in self.train_ds.rebatch(1).take(150) :
        #         yield [tf.dtypes.cast(data[0], tf.float32)]

        # For mnist dataset
        def representative_dataset():
            """
            Create a representative dataset for post-training quantization.
            Yields one image at a time, cast to tf.float32.
            """
            for i in range(150):  # Take the first 150 samples as representative data
                image = self.train_images[i]  # Access image from the preloaded MNIST dataset
                image = np.expand_dims(image, axis=0)  # Add batch dimension
                yield [tf.dtypes.cast(image, tf.float32)]


        print("Quantization is Running...")
        model = tf.keras.models.load_model(f"{self.path_to_trained_models}/{self.model_name}.h5")
        converter = tf.lite.TFLiteConverter.from_keras_model(model)
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.representative_dataset = representative_dataset
        converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
        converter.inference_input_type = tf.uint8
        converter.inference_output_type = tf.uint8
        tflite_quant_model = converter.convert()

        with open(f"{self.path_to_trained_models}/{self.model_name}.tflite", 'wb') as f:
            f.write(tflite_quant_model)

        # FIXME: Delete h5 files later
        # os.remove(f"{self.path_to_trained_models}/{self.model_name}.h5")
        # print("--------.h file removed-------")


    def evaluate_flash_and_peak_RAM_occupancy(self) :
        # quantize model to evaluate its peak RAM occupancy and its Flash occupancy
        self.quantize_model_uint8()

        # evaluate its peak RAM occupancy and its Flash occupancy using STMicroelectronics' X-CUBE-AI
        # NOTE: Since this tflite file for the entire model, this should work
        proc = subprocess.Popen(
            ["./stm32tflm", f"{self.path_to_trained_models}/{self.model_name}.tflite"],
            stdout=subprocess.PIPE
        )
        try:
            outs, errs = proc.communicate(timeout=15)
            Flash, RAM = re.findall(r'\d+', str(outs))
        except subprocess.TimeoutExpired:
            proc.kill()
            outs, errs = proc.communicate()
            print("stm32tflm error")
            exit()

        return int(Flash), int(RAM)


    def evaluate_model_process(self, k, c) :
        name_of_accuracy = 'val_accuracy_final_exit'
        if c > 1:
            name_of_accuracy = 'final_base_model_accuracy_final_exit'    # Total number of exits (including final) = c + 1
        if k > 0 :
            self.model_name = f"k_{k}_c_{c}"
            print(f"\n----- Current Model: {self.model_name} -----\n")
            checkpoint = tf.keras.callbacks.ModelCheckpoint(
                f"{self.path_to_trained_models}/{self.model_name}.h5", monitor=name_of_accuracy,
                verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

            # ------ Find the model ------
            # NOTE: this model is the ENTIRE model (all chunks combined). Use this model to find RAM, FLASH, etc.
            model, MACC, number_of_cells_limited = self.Model(k, c)

            # # ------ Train the multi-exit model ------
            self.train_images, self.train_labels = self.dataset_to_numpy(self.train_ds)
            train_labels_multi = [self.train_labels] * (len(self.exits) + 1) # len(self.exits) + 1 = total number of exits
            self.test_images, self.test_labels = self.dataset_to_numpy(self.validation_ds)
            test_labels_multi = [self.test_labels] * (len(self.exits) + 1)

            # train_labels_multi = [self.train_labels] * (len(self.exits) + 1) # len(self.exits) + 1 = total number of exits
            # test_labels_multi = [self.test_labels] * (len(self.exits) + 1)

            if len(self.exits) == 0:
                train_labels_multi = self.train_labels
                test_labels_multi = self.test_labels

            # print(f"x_train shape: {self.train_images.shape}")
            # print(f"y_train shape: {train_labels_multi.shape}")

            # One epoch of training must be done before quantization, which is needed to evaluate RAM and Flash occupancy
            model.fit(
                self.train_images,
                train_labels_multi,
                epochs=1,
                batch_size=self.batch_size,
                validation_data=(self.test_images, test_labels_multi),
                validation_freq=1
            )
            model.save(f"{self.path_to_trained_models}/{self.model_name}.h5")

            Flash, RAM = self.evaluate_flash_and_peak_RAM_occupancy()
            print(f"\nRAM: {RAM},\t Flash: {Flash},\t MACC: {MACC}\n")

            # TODO: Measure RAM, MACC, FLASH -> AND measure the size of the file & decide to abort if it's beyond the hardware's memory capacity
            #if MACC <= self.max_MACC and Flash <= self.max_Flash and RAM <= self.max_RAM and not number_of_cells_limited :
                # ------ Now train it for (epochs - 1) times ------
            hist = model.fit(
                self.train_images,
                train_labels_multi,
                epochs=self.epochs - 1,
                batch_size=self.batch_size,
                validation_data=(self.test_images, test_labels_multi),
                validation_freq=1,
                callbacks=[checkpoint]
            )
            self.quantize_model_uint8()
            self.model = model

            print(hist.history.keys())

            # Return these info at the end
            # TODO: Add more items (ex. '1st exit accuracy', '2nd exit accuracy', '3rd exit accuracy', etc.)
            return {'k': k,
                    'c': c if not number_of_cells_limited else "Not feasible",
                    # 'RAM': RAM if RAM <= self.max_RAM else "Outside the upper bound",     # FIXME: later work on these hardware specs
                    # 'Flash': Flash if Flash <= self.max_Flash else "Outside the upper bound",
                    # 'MACC': MACC if MACC <= self.max_MACC else "Outside the upper bound",
                    'max_val_acc':
                    np.around(np.amax(hist.history[name_of_accuracy]), decimals=3)
                    if 'hist' in locals() else -3}
        else :
            return{'k': 'unfeasible', 'c': c, 'max_val_acc': -3}


    def convert_and_save_model_chunk(model_chunk, save_name, path, idx):
        """
        Save the model chunk in .tflite format
        """
        converter = tf.lite.TFLiteConverter.from_keras_model(model_chunk)
        tflite_model = converter.convert()
        open(f"{path}/{save_name}_{idx}.tflite", "wb").write(tflite_model)


    def save_architecture_info(self, k, c):
        """
        Save the best architecture's information to global list variables
        """
        global global_base_models
        global global_exits
        global best_model
        global best_c
        global best_k

        global_base_models = self.base_models
        global_exits = self.exits
        best_model = self.model

        best_c = c
        best_k = k


    def explore_num_cells(self, k) :
        previous_architecture = {'k': -1, 'c': -1, 'max_val_acc': -2}
        current_architecture = {'k': -1, 'c': -1, 'max_val_acc': -1}
        c = 1       #1 = only final exit. As c increases, number of exits increase (c=2 means 2 exits, etc.)
        k = int(k)

        # Only run the cell up to 1 (so 2 exits at max)
        while c <= 2:
            self.model_counter = self.model_counter + 1     # FIXME: probably not needed

            previous_architecture = current_architecture
            current_architecture = self.evaluate_model_process(k, c)
            print(f"\n\n\n{current_architecture}\n\n\n")

            # if we find better architecture, we record it
            if (current_architecture['max_val_acc'] > previous_architecture['max_val_acc']):
                self.save_architecture_info(k, c)

            c = c + 1
        return previous_architecture

    def search(self) :
        self.model_counter = 0
        epsilon = 0.005
        k0 = 4 # 4

        start = datetime.datetime.now()

        k = k0
        previous_architecture = self.explore_num_cells(k)
        # k = 2 * k
        current_architecture = self.explore_num_cells(k)

        # If max accuracy of current NN is > than prev. one -> set current one as default (prev)
        # if (current_architecture['max_val_acc'] > previous_architecture['max_val_acc']) :
        #     previous_architecture = current_architecture
        #     k = 2 * k
        #     current_architecture = self.explore_num_cells(k)
        #     # while(current_architecture['max_val_acc'] > previous_architecture['max_val_acc'] + epsilon) :
        #     #     previous_architecture = current_architecture
        #     #     k = 2 * k
        #     #     current_architecture = self.explore_num_cells(k)
        # else :
        #     k = k0 / 2
        #     current_architecture = self.explore_num_cells(k)
        #     # while(current_architecture['max_val_acc'] >= previous_architecture['max_val_acc']) :
        #     #     previous_architecture = current_architecture
        #     #     k = k / 2
        #     #     current_architecture = self.explore_num_cells(k)

        # FIXME: since above are commented out, resulting_architecture is previous_architecture (not accurate) -> FIX THIS LATER!
        if current_architecture['max_val_acc'] >= previous_architecture['max_val_acc']:
          resulting_architecture = current_architecture
        else:
          resulting_architecture = previous_architecture

        # ************************
        # *                      *
        # *  Final Architecture  *
        # *                      *
        # ************************

        end = datetime.datetime.now()

        final_model_folder_path = "final_result/"

        print(f"Check -- k: {resulting_architecture['k']} {best_k} c: {resulting_architecture['c']} {best_c}")

        # After finding the best architecture, make model_chunks from it & save in tflite files
        print("\n----- Generating model chunks from the best architecture found -----")
        if len(global_exits) != 0:  # if there's a global_exit (exits other than final one)
            self.find_multiple_model_chunks(folder_path=final_model_folder_path)

        # entire tflite file
        if (resulting_architecture['max_val_acc'] > 0) :
            resulting_architecture_name = f"k_{resulting_architecture['k']}_c_{resulting_architecture['c']}.tflite"
            self.path_to_resulting_architecture = f"resulting_architecture_{resulting_architecture_name}"
            os.rename(f"{self.path_to_trained_models}/{resulting_architecture_name}", self.path_to_resulting_architecture)
            os.system(f"rm -rf {self.path_to_trained_models}")
            shutil.move(self.path_to_resulting_architecture, final_model_folder_path)
            print(f"\n----- Best Resulting architecture: {resulting_architecture}-----\n")
        else :
            print(f"\nNo feasible architecture found\n")

        print(f"Elapsed time (search): {end-start}\n")

        return self.path_to_resulting_architecture

    def find_multiple_model_chunks(self, folder_path):
        """
        Converts the best model into multiple chunks of model, then create tflite files from each of them
        """

        model = best_model  # An entire model with multi-exits.

        # list to save split models
        split_model_exit_list = []
        split_base_model_list = []    # for split_base_model_#

        # first base model
        image_input = tf.keras.layers.Input(shape=self.input_shape, name='Input')
        z1 = global_base_models[0](image_input)
        split_base_model = tf.keras.Model(inputs=[image_input], outputs=[z1])
        split_base_model.summary()# split base_model1
        split_base_model_list.append(split_base_model)

        input_base_model_list = []
        input_base_model_list.append(image_input)

        # Find all split_model_exit and split_base_model
        n = len(global_exits)
        for idx in range(0, n):
            # split_model_exit
            input_exit = tf.keras.layers.Input(shape=model.get_layer(f"exit_{idx+1}").input_shape[1:])
            each_exit = global_exits[idx]
            split_model_exit = tf.keras.Model(inputs=[input_exit], outputs=[each_exit(input_exit)]) # out1 = exit1(z1)
            split_model_exit.summary()
            split_model_exit_list.append(split_model_exit)

        for idx in range(1, len(global_base_models)-1):
            # split_base_model
            input_base_model = tf.keras.layers.Input(shape=model.get_layer(f"base_model_{idx+1}").input_shape[1:])
            input_base_model_list.append(input_base_model)
            each_base_model = global_base_models[idx]
            split_base_model = tf.keras.Model(inputs=[input_base_model], outputs=[each_base_model(input_base_model)])
            split_base_model.summary()
            split_base_model_list.append(split_base_model)

        # final model (final exit) <- last split_base_model
        input_final_model = tf.keras.layers.Input(shape=model.get_layer("final_base_model").input_shape[1:])#z1 = base_model1(image_input); z2 = base_model2(z1);
        split_final_model = tf.keras.Model(inputs=[input_final_model], outputs=[global_base_models[-1](input_final_model)])# out3 = base_model3(z2)
        split_final_model.summary()# split base_model3


        opt = tf.keras.optimizers.Adam(learning_rate=self.learning_rate, clipvalue=1.0)  # NOTE: clipvalue for gradient clipping
        # ---------- Just check the first exit to see if it works (since there are multiple exits, it is difficult to automate this) ----------
        model_pass_1 = tf.keras.Model(inputs=[image_input], outputs=[split_model_exit_list[0](split_base_model_list[0](image_input))])
        # model_pass_1.compile(optimizer='adam',
        #         loss=[tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)],
        #         metrics=['accuracy']
        # )
        model_pass_1.compile(optimizer=opt,
                loss=['categorical_crossentropy'],
                metrics=['accuracy']
        )

        # ---------- prepare for model chunks ----------

        split_input_list = []   # save split_z1, z2, etc.
        split_out_list = []     # save split_out1, out2, etc.

        for idx in range(0, len(split_model_exit_list)):
            input_base_model = input_base_model_list[idx]
            split_input = split_base_model_list[idx](input_base_model)  # split_z
            split_out = split_model_exit_list[idx](split_input)         # split_out

            split_input_list.append(split_input)
            split_out_list.append(split_out)

        # final (last split_out) -> don't save in list
        split_out = split_final_model(input_final_model)

        # ---------- Create model chunks -----------

        model_chunk_list = [] # save model_chunk

        model_chunk = tf.keras.Model(inputs=[image_input], outputs=[split_out_list[0], split_input_list[0]])  # 1st model_chunk (image_input). outputs=[output, mid feature]
        model_chunk_list.append(model_chunk)  # model chunk 1

        for idx in range(1, len(split_out_list)):  # split_out_list & split_input_list have same # of contents
            model_chunk = tf.keras.Model(inputs=[input_base_model_list[idx]], outputs=[split_out_list[idx], split_input_list[idx]])
            model_chunk_list.append(model_chunk)

        # model_chunk = tf.keras.Model(inputs=[input_base_model_list[1]], outputs=[split_out_list[1], split_input_list[1]])
        # model_chunk_list.append(model_chunk)  # model chunk 2

        # last split_out
        model_chunk = tf.keras.Model(inputs=[input_final_model], outputs=[split_out, split_out]) # final model chunk
        model_chunk_list.append(model_chunk)

        # ----------- now, iterate through the model_chunk & compile them -------------
        # opt = tf.keras.optimizers.Adam(learning_rate=self_learning_rate, clipvalue=1.0)  # NOTE: clipvalue for gradient clipping

        # Since there are multiple exits, you need multiple metrics for each exit (including final exit) w/ different metric names
        metrics_list = []
        for i in range(1, best_c):   # global_exits = best_c
            metrics_list.append([tf.keras.metrics.CategoricalAccuracy(name=f'accuracy_exit_{i}')])
        metrics_list.append([tf.keras.metrics.CategoricalAccuracy(name=f'accuracy_final_exit')])

        # model.compile(optimizer='adam',
        #             loss=[tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)] * best_c,
        #             metrics=metrics_list)

        # for model_chunk in model_chunk_list:
        #     model_chunk.compile(optimizer='adam',
        #             loss=[tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)],
        #             metrics=['accuracy']
        #     )

        model.compile(optimizer=opt,
                  loss=['categorical_crossentropy'] * (len(self.exits) + 1),
                  metrics=metrics_list)

        for model_chunk in model_chunk_list:
            model_chunk.compile(optimizer=opt,
                    loss=['categorical_crossentropy'],
                    metrics=['accuracy']
            )

        # ------------ Test 1st and final exit -------------
        print("----- Testing model chunks -----")
        scores = model_pass_1.evaluate(self.test_images, self.test_labels, verbose=2)
        print("First exit Test Loss:", scores[0])
        print("First exit Test Accuracy:", scores[1])

        scores = model.evaluate(self.test_images, self.test_labels, verbose=2)
        print("Entire Model Test Loss:", scores[0])
        print("Entire Model Test Accuracy:", scores[1])

        # ------------ Save these model chunks in a separate folder ----------
        if os.path.exists(folder_path):   # if folder exists, delete it
            os.system(f"rm -rf {folder_path}")

        os.makedirs(folder_path)
        for idx, model_chunk in enumerate(model_chunk_list):
            self.convert_and_save_model_chunk(model_chunk, f"k_{best_k}_c_{best_c}_model_chunk", folder_path, idx)

        print(f"----- Successfully saved the model chunks in folder {folder_path} -----")


    def convert_and_save_model_chunk(self, model_chunk, save_name, path, idx):
        """
        Save the model chunk in .tflite format
        """
        converter = tf.lite.TFLiteConverter.from_keras_model(model_chunk)
        tflite_model = converter.convert()
        open(f"{path}/{save_name}_{idx}.tflite", "wb").write(tflite_model)  # TODO: print tflite chunkfile sizes as well

# %% [markdown]
# Upload the stm32tflm script in the files folder of Google Colaboratory's VM

# %% [markdown]
# Enable its execution

# %%
# !chmod +x stm32tflm

# %% [markdown]
# Unzip the zip file of datasets you uploaded (I used https://www.kaggle.com/datasets/hasnainjaved/melanoma-skin-cancer-dataset-of-10000-images?resource=download)

# %%
# !unzip zipfile.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_643.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_644.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_645.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_646.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_647.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_648.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_649.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_65.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_650.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_651.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_652.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_653.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_654.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_655.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_656.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_657.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_658.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_659.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_66.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_660.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_661.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_662.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_663.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_664.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_665.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_666.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_667.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_668.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_669.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_67.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_670.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_671.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_672.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_673.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_674.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_675.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_676.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_677.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_678.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_679.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_68.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_680.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_681.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_682.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_683.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_684.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_685.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_686.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_687.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_688.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_689.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_69.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_690.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_691.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_692.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_693.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_694.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_695.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_696.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_697.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_698.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_699.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_7.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_70.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_700.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_701.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_702.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_703.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_704.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_705.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_706.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_707.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_708.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_709.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_71.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_710.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_711.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_712.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_713.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_714.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_715.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_716.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_717.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_718.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_719.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_72.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_720.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_721.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_722.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_723.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_724.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_725.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_726.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_727.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_728.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_729.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_73.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_730.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_731.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_732.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_733.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_734.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_735.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_736.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_737.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_738.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_739.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_74.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_740.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_741.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_742.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_743.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_744.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_745.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_746.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_747.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_748.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_749.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_75.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_750.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_751.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_752.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_753.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_754.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_755.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_756.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_757.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_758.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_759.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_76.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_760.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_761.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_762.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_763.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_764.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_765.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_766.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_767.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_768.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_769.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_77.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_770.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_771.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_772.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_773.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_774.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_775.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_776.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_777.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_778.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_779.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_78.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_780.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_781.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_782.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_783.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_784.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_785.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_786.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_787.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_788.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_789.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_79.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_790.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_791.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_792.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_793.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_794.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_795.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_796.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_797.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_798.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_799.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_8.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_80.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_800.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_801.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_802.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_803.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_804.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_805.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_806.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_807.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_808.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_809.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_81.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_810.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_811.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_812.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_813.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_814.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_815.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_816.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_817.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_818.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_819.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_82.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_820.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_821.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_822.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_823.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_824.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_825.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_826.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_827.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_828.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_829.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_83.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_830.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_831.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_832.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_833.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_834.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_835.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_836.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_837.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_838.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_839.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_84.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_840.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_841.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_842.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_843.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_844.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_845.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_846.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_847.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_848.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_849.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_85.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_850.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_851.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_852.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_853.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_854.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_855.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_856.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_857.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_858.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_859.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_86.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_860.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_861.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_862.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_863.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_864.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_865.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_866.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_867.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_868.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_869.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_87.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_870.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_871.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_872.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_873.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_874.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_875.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_876.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_877.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_878.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_879.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_88.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_880.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_881.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_882.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_883.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_884.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_885.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_886.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_887.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_888.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_889.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_89.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_890.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_891.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_892.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_893.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_894.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_895.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_896.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_897.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_898.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_899.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_9.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_90.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_900.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_901.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_902.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_903.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_904.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_905.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_906.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_907.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_908.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_909.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_91.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_910.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_911.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_912.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_913.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_914.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_915.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_916.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_917.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_918.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_919.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_92.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_920.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_921.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_922.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_923.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_924.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_925.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_926.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_927.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_928.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_929.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_93.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_930.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_931.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_932.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_933.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_934.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_935.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_936.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_937.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_938.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_939.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_94.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_940.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_941.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_942.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_943.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_944.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_945.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_946.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_947.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_948.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_949.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_95.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_950.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_951.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_952.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_953.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_954.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_955.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_956.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_957.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_958.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_959.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_96.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_960.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_961.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_962.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_963.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_964.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_965.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_966.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_967.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_968.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_969.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_97.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_970.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_971.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_972.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_973.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_974.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_975.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_976.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_977.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_978.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_979.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_98.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_980.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_981.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_982.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_983.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_984.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_985.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_986.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_987.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_988.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_989.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_99.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_990.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_991.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_992.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_993.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_994.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_995.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_996.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_997.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_998.jpg
#   inflating: melanoma_cancer_dataset/train/benign/melanoma_999.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5000.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5001.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5002.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5003.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5004.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5005.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5006.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5007.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5008.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5009.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5010.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5011.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5012.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5013.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5014.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5015.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5016.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5017.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5018.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5019.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5020.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5021.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5022.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5023.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5024.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5025.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5026.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5027.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5028.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5029.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5030.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5031.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5032.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5033.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5034.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5035.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5036.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5037.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5038.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5039.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5040.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5041.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5042.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5043.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5044.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5045.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5046.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5047.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5048.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5049.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5050.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5051.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5052.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5053.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5054.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5055.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5056.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5057.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5058.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5059.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5060.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5061.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5062.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5063.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5064.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5065.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5066.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5067.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5068.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5069.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5070.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5071.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5072.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5073.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5074.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5075.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5076.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5077.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5078.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5079.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5080.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5081.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5082.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5083.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5084.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5085.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5086.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5087.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5088.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5089.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5090.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5091.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5092.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5093.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5094.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5095.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5096.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5097.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5098.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5099.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5100.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5101.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5102.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5103.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5104.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5105.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5106.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5107.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5108.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5109.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5110.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5111.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5112.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5113.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5114.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5115.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5116.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5117.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5118.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5119.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5120.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5121.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5122.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5123.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5124.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5125.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5126.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5127.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5128.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5129.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5130.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5131.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5132.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5133.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5134.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5135.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5136.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5137.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5138.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5139.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5140.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5141.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5142.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5143.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5144.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5145.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5146.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5147.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5148.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5149.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5150.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5151.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5152.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5153.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5154.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5155.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5156.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5157.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5158.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5159.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5160.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5161.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5162.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5163.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5164.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5165.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5166.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5167.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5168.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5169.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5170.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5171.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5172.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5173.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5174.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5175.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5176.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5177.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5178.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5179.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5180.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5181.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5182.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5183.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5184.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5185.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5186.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5187.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5188.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5189.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5190.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5191.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5192.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5193.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5194.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5195.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5196.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5197.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5198.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5199.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5200.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5201.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5202.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5203.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5204.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5205.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5206.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5207.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5208.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5209.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5210.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5211.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5212.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5213.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5214.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5215.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5216.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5217.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5218.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5219.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5220.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5221.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5222.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5223.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5224.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5225.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5226.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5227.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5228.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5229.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5230.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5231.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5232.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5233.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5234.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5235.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5236.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5237.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5238.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5239.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5240.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5241.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5242.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5243.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5244.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5245.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5246.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5247.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5248.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5249.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5250.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5251.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5252.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5253.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5254.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5255.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5256.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5257.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5258.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5259.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5260.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5261.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5262.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5263.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5264.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5265.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5266.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5267.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5268.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5269.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5270.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5271.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5272.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5273.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5274.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5275.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5276.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5277.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5278.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5279.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5280.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5281.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5282.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_5283.jpg
# ...
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9386.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9387.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9388.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9389.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9390.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9391.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9392.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9393.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9394.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9395.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9396.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9397.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9398.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9399.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9400.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9401.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9402.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9403.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9404.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9405.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9406.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9407.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9408.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9409.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9410.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9411.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9412.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9413.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9414.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9415.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9416.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9417.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9418.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9419.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9420.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9421.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9422.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9423.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9424.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9425.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9426.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9427.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9428.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9429.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9430.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9431.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9432.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9433.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9434.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9435.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9436.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9437.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9438.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9439.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9440.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9441.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9442.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9443.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9444.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9445.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9446.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9447.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9448.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9449.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9450.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9451.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9452.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9453.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9454.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9455.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9456.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9457.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9458.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9459.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9460.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9461.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9462.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9463.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9464.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9465.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9466.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9467.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9468.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9469.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9470.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9471.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9472.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9473.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9474.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9475.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9476.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9477.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9478.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9479.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9480.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9481.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9482.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9483.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9484.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9485.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9486.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9487.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9488.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9489.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9490.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9491.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9492.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9493.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9494.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9495.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9496.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9497.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9498.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9499.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9500.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9501.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9502.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9503.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9504.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9505.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9506.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9507.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9508.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9509.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9510.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9511.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9512.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9513.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9514.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9515.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9516.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9517.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9518.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9519.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9520.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9521.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9522.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9523.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9524.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9525.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9526.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9527.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9528.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9529.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9530.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9531.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9532.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9533.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9534.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9535.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9536.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9537.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9538.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9539.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9540.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9541.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9542.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9543.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9544.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9545.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9546.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9547.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9548.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9549.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9550.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9551.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9552.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9553.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9554.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9555.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9556.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9557.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9558.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9559.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9560.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9561.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9562.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9563.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9564.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9565.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9566.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9567.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9568.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9569.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9570.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9571.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9572.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9573.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9574.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9575.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9576.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9577.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9578.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9579.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9580.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9581.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9582.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9583.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9584.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9585.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9586.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9587.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9588.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9589.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9590.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9591.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9592.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9593.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9594.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9595.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9596.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9597.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9598.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9599.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9600.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9601.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9602.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9603.jpg
#   inflating: melanoma_cancer_dataset/train/malignant/melanoma_9604.jpg

# %% [markdown]
# #Example of usage

# %%
import kagglehub
import shutil

# Download latest version
path = kagglehub.dataset_download("constantinwerner/human-detection-dataset")

print("Path to dataset files:", path)

# Move the folder to current directory
path = shutil.move(path, "/content")

main_dir = path + "/human detection dataset"
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/constantinwerner/human-detection-dataset?dataset_version_number=5...
# 100%|██████████| 260M/260M [00:03<00:00, 73.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/constantinwerner/human-detection-dataset/versions/5

# %%
import numpy as np
import tensorflow as tf

input_shape = (50,50,3)
# input_shape = [28,28]

#target: STM32L412KBU3
#273 CoreMark, 40 kiB RAM, 128 kiB Flash
peak_RAM_upper_bound = 40960
Flash_upper_bound = 131072
MACC_upper_bound = 2730000  #CoreMark * 1e4

path_to_training_set = './melanoma_cancer_dataset/train'
#path_to_training_set = main_dir
val_split = 0.3

#whether or not to cache datasets in memory
#if the dataset cannot fit in the main memory, the application will crash
cache = True

# *************************
# *                       *
# * where to save results *
# *                       *
# *************************
save_path = './results_1'

#to show the GPU used
# !nvidia-smi

colabNAS = ColabNAS(
    peak_RAM_upper_bound,
    Flash_upper_bound,
    MACC_upper_bound,
    path_to_training_set,
    val_split,
    cache,
    input_shape,
    save_path=save_path
)

# search for the model TODO: make it so that search() returns the entire tflite model + name of model chunks
path_to_tflite_model = colabNAS.search()
print(f"path_to_tflite_model: {path_to_tflite_model}")
# Out:
# Thu Feb 20 15:23:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Found 9605 files belonging to 2 classes.
# Using 6724 files for training.
# Found 9605 files belonging to 2 classes.
# Using 2881 files for validation.
#
# ----- Current Model: k_4_c_1 -----
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 50, 50, 3)]       0
#
#  final_base_model (Sequenti  (None, 2)                 5126
#  al)
#
# =================================================================
# Total params: 5126 (20.02 KB)
# Trainable params: 5120 (20.00 KB)
# Non-trainable params: 6 (24.00 Byte)
# _________________________________________________________________
# 53/53 [==============================] - 11s 192ms/step - loss: 0.4941 - accuracy_final_exit: 0.7594 - val_loss: 0.8228 - val_accuracy_final_exit: 0.5449
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# RAM: 20480,	 Flash: 9648,	 MACC: 0
#
# 53/53 [==============================] - ETA: 0s - loss: 0.3886 - accuracy_final_exit: 0.8322
# Epoch 1: val_accuracy_final_exit improved from -inf to 0.72961, saving model to ./results_1/trained_models/k_4_c_1.h5
# 53/53 [==============================] - 10s 195ms/step - loss: 0.3886 - accuracy_final_exit: 0.8322 - val_loss: 0.5108 - val_accuracy_final_exit: 0.7296
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# dict_keys(['loss', 'accuracy_final_exit', 'val_loss', 'val_accuracy_final_exit'])
#
#
#
# {'k': 4, 'c': 1, 'max_val_acc': 0.73}
#
#
#
#
# ----- Current Model: k_4_c_2 -----
#
# ---exit_1 being added---
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 50, 50, 3)]          0         []
#
#  base_model_1 (Sequential)   (None, 50, 50, 4)            124       ['input[0][0]']
#
#  exit_1 (Sequential)         (None, 2)                    5002      ['base_model_1[0][0]']
#
#  final_base_model (Sequenti  (None, 2)                    10298     ['base_model_1[0][0]']
#  al)
#
# ==================================================================================================
# Total params: 15424 (60.25 KB)
# Trainable params: 15418 (60.23 KB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________
# 53/53 [==============================] - 19s 326ms/step - loss: 0.9132 - exit_1_loss: 0.4469 - final_base_model_loss: 0.4663 - exit_1_accuracy_exit_1: 0.7827 - final_base_model_accuracy_final_exit: 0.7631 - val_loss: 1.3843 - val_exit_1_loss: 0.7024 - val_final_base_model_loss: 0.6819 - val_exit_1_accuracy_exit_1: 0.6133 - val_final_base_model_accuracy_final_exit: 0.6071
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# RAM: 34304,	 Flash: 22240,	 MACC: 0
#
# 53/53 [==============================] - ETA: 0s - loss: 0.7085 - exit_1_loss: 0.3526 - final_base_model_loss: 0.3558 - exit_1_accuracy_exit_1: 0.8462 - final_base_model_accuracy_final_exit: 0.8474
# Epoch 1: final_base_model_accuracy_final_exit improved from -inf to 0.84741, saving model to ./results_1/trained_models/k_4_c_2.h5
# 53/53 [==============================] - 17s 325ms/step - loss: 0.7085 - exit_1_loss: 0.3526 - final_base_model_loss: 0.3558 - exit_1_accuracy_exit_1: 0.8462 - final_base_model_accuracy_final_exit: 0.8474 - val_loss: 1.0867 - val_exit_1_loss: 0.5369 - val_final_base_model_loss: 0.5498 - val_exit_1_accuracy_exit_1: 0.7032 - val_final_base_model_accuracy_final_exit: 0.6914
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# dict_keys(['loss', 'exit_1_loss', 'final_base_model_loss', 'exit_1_accuracy_exit_1', 'final_base_model_accuracy_final_exit', 'val_loss', 'val_exit_1_loss', 'val_final_base_model_loss', 'val_exit_1_accuracy_exit_1', 'val_final_base_model_accuracy_final_exit'])
#
#
#
# {'k': 4, 'c': 2, 'max_val_acc': 0.847}
#
#
#
#
# ----- Current Model: k_4_c_1 -----
#
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 50, 50, 3)]       0
#
#  final_base_model (Sequenti  (None, 2)                 5126
#  al)
#
# =================================================================
# Total params: 5126 (20.02 KB)
# Trainable params: 5120 (20.00 KB)
# Non-trainable params: 6 (24.00 Byte)
# _________________________________________________________________
# 53/53 [==============================] - 11s 177ms/step - loss: 0.5190 - accuracy_final_exit: 0.7485 - val_loss: 0.7571 - val_accuracy_final_exit: 0.5793
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# RAM: 20480,	 Flash: 9720,	 MACC: 0
#
# 53/53 [==============================] - ETA: 0s - loss: 0.3621 - accuracy_final_exit: 0.8391
# Epoch 1: val_accuracy_final_exit improved from -inf to 0.71711, saving model to ./results_1/trained_models/k_4_c_1.h5
# 53/53 [==============================] - 9s 171ms/step - loss: 0.3621 - accuracy_final_exit: 0.8391 - val_loss: 0.5245 - val_accuracy_final_exit: 0.7171
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# dict_keys(['loss', 'accuracy_final_exit', 'val_loss', 'val_accuracy_final_exit'])
#
#
#
# {'k': 4, 'c': 1, 'max_val_acc': 0.717}
#
#
#
#
# ----- Current Model: k_4_c_2 -----
#
# ---exit_1 being added---
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 50, 50, 3)]          0         []
#
#  base_model_1 (Sequential)   (None, 50, 50, 4)            124       ['input[0][0]']
#
#  exit_1 (Sequential)         (None, 2)                    5002      ['base_model_1[0][0]']
#
#  final_base_model (Sequenti  (None, 2)                    10298     ['base_model_1[0][0]']
#  al)
#
# ==================================================================================================
# Total params: 15424 (60.25 KB)
# Trainable params: 15418 (60.23 KB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________
# 53/53 [==============================] - 18s 317ms/step - loss: 0.9846 - exit_1_loss: 0.4638 - final_base_model_loss: 0.5207 - exit_1_accuracy_exit_1: 0.7820 - final_base_model_accuracy_final_exit: 0.7397 - val_loss: 1.2854 - val_exit_1_loss: 0.6666 - val_final_base_model_loss: 0.6189 - val_exit_1_accuracy_exit_1: 0.6387 - val_final_base_model_accuracy_final_exit: 0.6005
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# RAM: 34304,	 Flash: 22240,	 MACC: 0
#
# 53/53 [==============================] - ETA: 0s - loss: 0.7238 - exit_1_loss: 0.3562 - final_base_model_loss: 0.3676 - exit_1_accuracy_exit_1: 0.8499 - final_base_model_accuracy_final_exit: 0.8428
# Epoch 1: final_base_model_accuracy_final_exit improved from -inf to 0.84280, saving model to ./results_1/trained_models/k_4_c_2.h5
# 53/53 [==============================] - 18s 349ms/step - loss: 0.7238 - exit_1_loss: 0.3562 - final_base_model_loss: 0.3676 - exit_1_accuracy_exit_1: 0.8499 - final_base_model_accuracy_final_exit: 0.8428 - val_loss: 1.0227 - val_exit_1_loss: 0.5420 - val_final_base_model_loss: 0.4807 - val_exit_1_accuracy_exit_1: 0.7126 - val_final_base_model_accuracy_final_exit: 0.7504
# Quantization is Running...
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /usr/local/lib/python3.11/dist-packages/tensorflow/lite/python/convert.py:953: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# dict_keys(['loss', 'exit_1_loss', 'final_base_model_loss', 'exit_1_accuracy_exit_1', 'final_base_model_accuracy_final_exit', 'val_loss', 'val_exit_1_loss', 'val_final_base_model_loss', 'val_exit_1_accuracy_exit_1', 'val_final_base_model_accuracy_final_exit'])
#
#
#
# {'k': 4, 'c': 2, 'max_val_acc': 0.843}
#
#
#
# Check -- k: 4 4 c: 1 2
#
# ----- Generating model chunks from the best architecture found -----
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 50, 50, 3)]       0
#
#  base_model_1 (Sequential)   (None, 50, 50, 4)         124
#
# =================================================================
# Total params: 124 (496.00 Byte)
# Trainable params: 118 (472.00 Byte)
# Non-trainable params: 6 (24.00 Byte)
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 50, 50, 4)]       0
#
#  exit_1 (Sequential)         (None, 2)                 5002
#
# =================================================================
# Total params: 5002 (19.54 KB)
# Trainable params: 5002 (19.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 50, 50, 4)]       0
#
#  final_base_model (Sequenti  (None, 2)                 10298
#  al)
#
# =================================================================
# Total params: 10298 (40.23 KB)
# Trainable params: 10298 (40.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ----- Testing model chunks -----
# 91/91 - 1s - loss: 0.5420 - accuracy: 0.7126 - 1s/epoch - 14ms/step
# First exit Test Loss: 0.5419735312461853
# First exit Test Accuracy: 0.7125998139381409
# 91/91 - 2s - loss: 1.0227 - exit_1_loss: 0.5420 - final_base_model_loss: 0.4807 - exit_1_accuracy_exit_1: 0.7126 - final_base_model_accuracy_final_exit: 0.7504 - 2s/epoch - 25ms/step
# Entire Model Test Loss: 1.0227011442184448
# Entire Model Test Accuracy: 0.5419735312461853
# ----- Successfully saved the model chunks in folder final_result/ -----
#
# ----- Best Resulting architecture: {'k': 4, 'c': 1, 'max_val_acc': 0.73}-----
#
# Elapsed time (search): 0:02:36.655914
#
# path_to_tflite_model: resulting_architecture_k_4_c_1.tflite

# %% [markdown]
# # Testing

# %% [markdown]
# ### Testing each model chunk

# %% [markdown]
# ### Testing the Entire Tflite Model

# %%
# Confidence-based method
# NOTE: Confidence is almost always 1 or 0 in this model. So even if confidence_threshold is 0.95, since the confidence of exit_1 is so high(1),
#       almost always it calls exit_1 (first exit)

import tensorflow as tf
from tqdm import tqdm
import numpy as np

def test_entire_model(path_to_resulting_architecture, test_ds, confidence_threshold=0.7):
    # Initialize the TFLite interpreter
    interpreter = tf.lite.Interpreter(model_path=path_to_resulting_architecture)
    interpreter.allocate_tensors()

    # Get input and output details
    input_details = interpreter.get_input_details()[0]  # Assume single input
    output_details = interpreter.get_output_details()  # Multiple outputs (for multi-exits)

    print(interpreter.get_input_details()[0])
    print(interpreter.get_output_details())

    # Initialize counters for correct and incorrect predictions
    correct = 0
    wrong = 0

    # Initialize counters for exit usage and confidence accumulation
    exit_counts = [0] * len(output_details)  # Track how many times each exit is used
    exit_confidences = [0.0] * len(output_details)  # Accumulate confidence scores for each exit

    # Iterate over the test dataset
    # NOTE: test each image, compare with confidence threshold to decide which exit to use
    for image, label in tqdm(test_ds, desc="Evaluating", unit="image"):
        # Preprocess image for quantized models if necessary
        if input_details['dtype'] == tf.uint8:
            input_scale, input_zero_point = input_details["quantization"]
            image = image / input_scale + input_zero_point
        # input_data = tf.dtypes.cast(image, tf.uint8)
        input_data = tf.dtypes.cast(image, tf.float32)

        # Set the input tensor
        interpreter.set_tensor(input_details['index'], input_data)

        # Run inference
        interpreter.invoke()

        # Check each exit for early exit condition (except for the last exit)
        prediction_made = False
        for exit_index, output in enumerate(output_details[:-1]):

            # Get output tensor for this exit
            exit_output = interpreter.get_tensor(output['index'])

            # NOTE: since exit_output[0] array has been already quantized (uint8 type), convert it into 'float' so that softmax can be applied
            # softmax does not support uint8 type
            exit_output = exit_output.astype("float")
            probabilities = tf.nn.softmax(exit_output[0])  # Apply softmax to get class probabilities
            # confidence = max(probabilities)  # Highest probability as confidence
            confidence = tf.reduce_max(probabilities)  # Highest probability as confidence

            # Check if confidence meets the threshold
            if confidence >= confidence_threshold:
                print(f"exit taken: {exit_index } with confidence: {confidence}")

                predicted_label = probabilities.numpy().argmax()
                actual_label = label.numpy().argmax()

                # Update correct/wrong counters based on prediction
                if predicted_label == actual_label:
                    correct += 1
                    print("predicted correctly!")
                else:
                    wrong += 1
                    print("predicted incorectly..")

                # Track exit usage and accumulate confidence
                exit_counts[exit_index] += 1
                exit_confidences[exit_index] += confidence

                prediction_made = True
                break  # Exit early since threshold is met

        # If no exit met the threshold, use the final exit output (since for loop goes through 0~1 before final exit, we need this)
        if not prediction_made:
            final_exit_output = interpreter.get_tensor(output_details[-1]['index'])
            final_probabilities = tf.nn.softmax(final_exit_output[0].astype(np.float32))
            # print(f"final exit_index: {exit_index}, probability: {probabilities}")
            confidence = tf.reduce_max(final_probabilities)
            predicted_label = final_probabilities.numpy().argmax()
            actual_label = label.numpy().argmax()

            if predicted_label == actual_label:
                correct += 1
            else:
                wrong += 1

            # Track the final exit usage and accumulate confidence
            exit_counts[-1] += 1
            exit_confidences[-1] += confidence

    # Calculate and print accuracy
    accuracy = correct / (correct + wrong)
    print(f"\nTotal # of Images: {correct + wrong} TFLite model overall test accuracy with multi-exit: {accuracy:.4f}")

    # Calculate average confidence for each exit
    average_confidences = [
        exit_confidences[i] / exit_counts[i] if exit_counts[i] > 0 else 0
        for i in range(len(exit_counts))
    ]

    # Print the exit statistics
    for i, (count, avg_conf) in enumerate(zip(exit_counts, average_confidences)):
        print(f"Exit {i+1}: taken {count} times, average confidence = {avg_conf:.4f}")

# %%
def test_multi_exit_model_chunk(tflite_files, test_ds):

  # Constant
  confidence_threshold = 0.7

  # Initialize the interpreter
  interpreters = [tf.lite.Interpreter(model_path=str(tflite_file)) for tflite_file in tflite_files]
  input_details = []
  output_details = []
  for interpreter in interpreters:
    interpreter.allocate_tensors()

    # print(interpreter.get_output_details())

    input_details.append(interpreter.get_input_details()[0])
    output_details.append(interpreter.get_output_details())

  print(input_details)
  print(output_details)

  # Initialize counters for correct and incorrect predictions
  correct = 0
  wrong = 0

  # Initialize counters for exit usage and confidence accumulation
  exit_counts = [0] * len(output_details)  # Track how many times each exit is used
  exit_confidences = [0.0] * len(output_details)  # Accumulate confidence scores for each exit

  # Iterate over the test dataset
  # NOTE: test each image, compare with confidence threshold to decide which exit to use
  for image, label in tqdm(test_ds, desc="Evaluating", unit="image"):

      # Preprocess image for quantized models if necessary
      if input_details[0]['dtype'] == tf.uint8:
          input_scale, input_zero_point = input_details[0]["quantization"]
          image = image / input_scale + input_zero_point

      # input_data = tf.dtypes.cast(image, tf.uint8)
      input_data = tf.dtypes.cast(image, tf.float32)

      # Check each exit for early exit condition (except for the last exit)
      prediction_made = False

      image = np.expand_dims(image, axis=0).astype(input_details[0]["dtype"])
      mid_feature = image
      exit_idx = 0
      for model_idx, interpreter in enumerate(interpreters):
        if len(mid_feature.shape) == 5:
          mid_feature = np.squeeze(mid_feature, axis=1)  # Removes the second axis
        interpreter.set_tensor(input_details[model_idx]["index"], mid_feature)  # Set the input tensor
        interpreter.invoke()  # Run inference

        # FIXME: idk why, but odd-numbered tflite files have these reversed -> fix later
        if model_idx % 2 == 0:
          exit_output = interpreter.get_tensor(output_details[model_idx][0]["index"])[0]
          mid_feature = interpreter.get_tensor(output_details[model_idx][1]["index"])[0]
        else:
          mid_feature = interpreter.get_tensor(output_details[model_idx][0]["index"])[0]
          exit_output = interpreter.get_tensor(output_details[model_idx][1]["index"])[0]

        # print(f"\nmodel_idx: {model_idx}")
        # print(f"\n exit: {exit_output.shape}")
        # print(f"\n mid feature: {mid_feature.shape}")

        # update exit idx
        exit_idx = model_idx

        # NOTE: since exit_output array has been already quantized (uint8 type), convert it into 'float' so that softmax can be applied
        # softmax does not support uint8 type
        exit_output = exit_output.astype("float")
        probabilities = tf.nn.softmax(exit_output)  # Apply softmax to get class probabilities
        # confidence = max(probabilities)  # Highest probability as confidence
        confidence = tf.reduce_max(probabilities, axis=-1)  # Highest probability as confidence

        # Check if confidence meets the threshold -> if it does, exit
        if confidence >= confidence_threshold:
            print(f"exit taken: {model_idx} with confidence: {confidence}")

            predicted_label = probabilities.numpy().argmax()
            actual_label = tf.argmax(label, axis=-1).numpy() # NOTE: maybe lab IS actual_label <- check this later

            # Update correct/wrong counters based on prediction
            if predicted_label == actual_label:
                correct += 1
            else:
                wrong += 1

            # Track exit usage and accumulate confidence
            exit_counts[model_idx] += 1
            exit_confidences[model_idx] += confidence

            prediction_made = True
            break  # Exit early since threshold is met

        mid_feature = tf.expand_dims(mid_feature, axis=0)

  # Calculate and print accuracy
  print(f"Number of correct: {correct}, wrong: {wrong}")
  if correct == 0 and wrong == 0:
    return
  accuracy = correct / (correct + wrong)
  print(f"\nTotal # of Images: {correct + wrong} TFLite model overall test accuracy with multi-exit: {accuracy:.4f}")

  # Calculate average confidence for each exit
  average_confidences = [
      exit_confidences[i] / exit_counts[i] if exit_counts[i] > 0 else 0
      for i in range(len(exit_counts))
  ]

  # Print the exit statistics
  for i, (count, avg_conf) in enumerate(zip(exit_counts, average_confidences)):
      print(f"Exit {i+1}: taken {count} times, average confidence = {avg_conf:.4f}")

# %%
#Location of test dataset
# path_to_test_set = main_dir
path_to_test_set = './melanoma_cancer_dataset/test'

input_shape = (50,50,3)

test_ds = tf.keras.utils.image_dataset_from_directory(
    directory=path_to_test_set,
    labels='inferred',
    label_mode='categorical',
    color_mode='rgb',
    batch_size=1,
    image_size=input_shape[0:2],
    shuffle=True
)

# path_to_tflite_model = "/content/k_8_c_2_model_chunk_0.tflite"
# test_entire_model(path_to_tflite_model, test_ds)

test_multi_exit_model_chunk(["final_result/k_4_c_3_model_chunk_0.tflite", "final_result/k_4_c_3_model_chunk_1.tflite", "final_result/k_4_c_3_model_chunk_2.tflite"], test_ds)
# Out:
# Found 1000 files belonging to 2 classes.
# [{'name': 'serving_default_Input:0', 'index': 0, 'shape': array([ 1, 50, 50,  3], dtype=int32), 'shape_signature': array([-1, 50, 50,  3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'serving_default_input_17:0', 'index': 0, 'shape': array([ 1, 50, 50,  4], dtype=int32), 'shape_signature': array([-1, 50, 50,  4], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'serving_default_input_18:0', 'index': 0, 'shape': array([ 1, 50, 50,  8], dtype=int32), 'shape_signature': array([-1, 50, 50,  8], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# [[{'name': 'StatefulPartitionedCall:1', 'index': 19, 'shape': array([1, 2], dtype=int32), 'shape_signature': array([-1,  2], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'StatefulPartitionedCall:0', 'index': 15, 'shape': array([ 1, 50, 50,  4], dtype=int32), 'shape_signature': array([-1, 50, 50,  4], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}], [{'name': 'StatefulPartitionedCall:1', 'index': 6, 'shape': array([ 1, 50, 50,  8], dtype=int32), 'shape_signature': array([-1, 50, 50,  8], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'StatefulPartitionedCall:0', 'index': 10, 'shape': array([1, 2], dtype=int32), 'shape_signature': array([-1,  2], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}], [{'name': 'StatefulPartitionedCall:1', 'index': 10, 'shape': array([1, 2], dtype=int32), 'shape_signature': array([-1,  2], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}, {'name': 'StatefulPartitionedCall:1', 'index': 10, 'shape': array([1, 2], dtype=int32), 'shape_signature': array([-1,  2], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]]
# Evaluating:   3%|▎         | 32/1000 [00:00<00:03, 313.01image/s]
# exit taken: 0 with confidence: 0.7154272479680304
# exit taken: 2 with confidence: 0.7079778674649438
# exit taken: 0 with confidence: 0.7183035456708262
# exit taken: 0 with confidence: 0.7227151609001216
# exit taken: 0 with confidence: 0.7163921774140182
# exit taken: 0 with confidence: 0.7087977718358032
# exit taken: 0 with confidence: 0.7047769243917518
# exit taken: 0 with confidence: 0.7029466338515489
# exit taken: 0 with confidence: 0.7229299542628868
# exit taken: 0 with confidence: 0.7198922637611229
# exit taken: 0 with confidence: 0.720101944569204
# exit taken: 0 with confidence: 0.722900227921588
# exit taken: 0 with confidence: 0.7088033210491999
# exit taken: 0 with confidence: 0.7057686078594702
# exit taken: 0 with confidence: 0.7032608029451429
# exit taken: 0 with confidence: 0.7107737612195396
# exit taken: 0 with confidence: 0.7225473886874113
# exit taken: 0 with confidence: 0.7135949267571442
# Evaluating:   7%|▋         | 71/1000 [00:00<00:02, 352.81image/s]
# exit taken: 0 with confidence: 0.706301888419578
# exit taken: 0 with confidence: 0.708040652905218
# exit taken: 0 with confidence: 0.7137385700832605
# exit taken: 2 with confidence: 0.7165148401235033
# exit taken: 2 with confidence: 0.714834673582054
# Evaluating:  11%|█         | 107/1000 [00:00<00:02, 306.89image/s]
# exit taken: 1 with confidence: 0.7018419821017977
# exit taken: 0 with confidence: 0.7119235768460556
# exit taken: 0 with confidence: 0.7208931597627818
# exit taken: 0 with confidence: 0.7013576643299486
# exit taken: 0 with confidence: 0.7085084814136965
# exit taken: 0 with confidence: 0.7055770442854284
# exit taken: 0 with confidence: 0.721061965699569
# exit taken: 0 with confidence: 0.712425275740432
# exit taken: 0 with confidence: 0.7208369560445761
# exit taken: 0 with confidence: 0.7237835353694246
# exit taken: 2 with confidence: 0.7036697624409842
# exit taken: 0 with confidence: 0.7143487614560228
# exit taken: 0 with confidence: 0.7172553660901727
# exit taken: 0 with confidence: 0.7222972193372531
# Evaluating:  17%|█▋        | 169/1000 [00:00<00:02, 279.98image/s]
# exit taken: 0 with confidence: 0.7057229561837624
# exit taken: 1 with confidence: 0.7021529649035726
# exit taken: 0 with confidence: 0.7176156104056469
# exit taken: 0 with confidence: 0.7176307573413996
# exit taken: 0 with confidence: 0.7033339740014274
# exit taken: 2 with confidence: 0.7055319913560392
# exit taken: 0 with confidence: 0.7244642407658737
# exit taken: 0 with confidence: 0.7246972947582628
# exit taken: 0 with confidence: 0.718706227510883
# exit taken: 0 with confidence: 0.7230950797851249
# exit taken: 0 with confidence: 0.7199620512322376
# exit taken: 0 with confidence: 0.711842019903592
# exit taken: 2 with confidence: 0.7028346898461546
# exit taken: 0 with confidence: 0.7240251539222143
# exit taken: 0 with confidence: 0.7213461494018184
# exit taken: 0 with confidence: 0.7054780361676762
# exit taken: 0 with confidence: 0.7023650040789673
# exit taken: 0 with confidence: 0.7086225109069089
# Evaluating:  20%|█▉        | 198/1000 [00:00<00:02, 271.55image/s]
# exit taken: 0 with confidence: 0.7075551184736155
# exit taken: 0 with confidence: 0.7116387351955683
# exit taken: 0 with confidence: 0.7195069718620408
# exit taken: 0 with confidence: 0.7175989266915792
# exit taken: 0 with confidence: 0.712812061141217
# exit taken: 0 with confidence: 0.7213734620010481
# exit taken: 0 with confidence: 0.7241536507191961
# exit taken: 0 with confidence: 0.7233689087242705
# exit taken: 0 with confidence: 0.7037892424707597
# exit taken: 0 with confidence: 0.7100671602763513
# exit taken: 0 with confidence: 0.7229993805699145
# exit taken: 0 with confidence: 0.7229691354207923
# exit taken: 0 with confidence: 0.7151861381083661
# Evaluating:  23%|██▎       | 227/1000 [00:00<00:02, 275.10image/s]
# exit taken: 0 with confidence: 0.7233168916395538
# exit taken: 0 with confidence: 0.7196632566246519
# exit taken: 0 with confidence: 0.7200994843980307
# exit taken: 0 with confidence: 0.7054301442762987
# exit taken: 0 with confidence: 0.7067428767505248
# exit taken: 0 with confidence: 0.7007174859061595
# exit taken: 0 with confidence: 0.7117059559052447
# exit taken: 0 with confidence: 0.7038070125763853
# Evaluating:  26%|██▌       | 255/1000 [00:00<00:02, 265.27image/s]
# exit taken: 0 with confidence: 0.722055313552414
# exit taken: 0 with confidence: 0.72099130296056
# exit taken: 0 with confidence: 0.7151718386368118
# exit taken: 0 with confidence: 0.7190972451939227
# exit taken: 2 with confidence: 0.704762758324409
# exit taken: 0 with confidence: 0.7198314407208797
# exit taken: 1 with confidence: 0.703557991563509
# exit taken: 0 with confidence: 0.7225724213597307
# exit taken: 0 with confidence: 0.7217944722352225
# exit taken: 0 with confidence: 0.7194863266391712
# exit taken: 0 with confidence: 0.7209071874039925
# Evaluating:  28%|██▊       | 282/1000 [00:01<00:02, 262.21image/s]
# exit taken: 0 with confidence: 0.7213749580214969
# exit taken: 0 with confidence: 0.7178798082346276
# exit taken: 1 with confidence: 0.7073346271376164
# exit taken: 0 with confidence: 0.7019280236398828
# exit taken: 0 with confidence: 0.7168938001265378
# exit taken: 0 with confidence: 0.7210990790799112
# exit taken: 0 with confidence: 0.7210849880476693
# exit taken: 0 with confidence: 0.7167808358371155
# Evaluating:  31%|███       | 310/1000 [00:01<00:02, 265.61image/s]
# exit taken: 0 with confidence: 0.7195966826085942
# exit taken: 0 with confidence: 0.7179386054376709
# exit taken: 2 with confidence: 0.7122872030914815
# exit taken: 0 with confidence: 0.7204262559671193
# exit taken: 0 with confidence: 0.7000635123594439
# exit taken: 0 with confidence: 0.7249164587101791
# exit taken: 0 with confidence: 0.7218809313322622
# exit taken: 0 with confidence: 0.7231833442830866
# exit taken: 0 with confidence: 0.7162062499755839
# exit taken: 0 with confidence: 0.704427444629522
# exit taken: 0 with confidence: 0.7162924875177323
# exit taken: 0 with confidence: 0.7181782928210687
# exit taken: 0 with confidence: 0.7245775792116403
# exit taken: 0 with confidence: 0.7250805150857739
# exit taken: 0 with confidence: 0.7205849130295837
# exit taken: 0 with confidence: 0.711525452207006
# Evaluating:  34%|███▍      | 340/1000 [00:01<00:02, 274.81image/s]
# exit taken: 0 with confidence: 0.7224760375648152
# exit taken: 0 with confidence: 0.7080364397325778
# exit taken: 0 with confidence: 0.7132777484549331
# exit taken: 0 with confidence: 0.725544462303176
# exit taken: 0 with confidence: 0.7216657399767958
# exit taken: 0 with confidence: 0.7115226757845131
# exit taken: 1 with confidence: 0.7002209347991123
# exit taken: 0 with confidence: 0.7081691602175112
# exit taken: 0 with confidence: 0.721909800958156
# Evaluating:  37%|███▋      | 369/1000 [00:01<00:02, 279.08image/s]
# exit taken: 2 with confidence: 0.7109368843882473
# exit taken: 0 with confidence: 0.7160767219815408
# exit taken: 0 with confidence: 0.7207864962098987
# exit taken: 0 with confidence: 0.7107996798574823
# exit taken: 0 with confidence: 0.7209254099501257
# exit taken: 0 with confidence: 0.7290853967024917
# exit taken: 0 with confidence: 0.7221380458696006
# exit taken: 0 with confidence: 0.7153512192668265
# exit taken: 0 with confidence: 0.7155144282039597
# exit taken: 0 with confidence: 0.7194284971114875
# Evaluating:  40%|███▉      | 397/1000 [00:01<00:02, 278.21image/s]
# exit taken: 0 with confidence: 0.7244469860579918
# exit taken: 0 with confidence: 0.7232507860047889
# exit taken: 0 with confidence: 0.715556360110657
# exit taken: 0 with confidence: 0.7248861086553
# exit taken: 0 with confidence: 0.714001883195742
# exit taken: 0 with confidence: 0.7058573680824699
# exit taken: 0 with confidence: 0.721140681695874
# exit taken: 0 with confidence: 0.7211699033641326
# exit taken: 0 with confidence: 0.7202199827086732
# Evaluating:  46%|████▌     | 455/1000 [00:01<00:01, 283.17image/s]
# exit taken: 0 with confidence: 0.7045809936415149
# exit taken: 0 with confidence: 0.7207763432930766
# exit taken: 0 with confidence: 0.7188178121470896
# exit taken: 0 with confidence: 0.7144114540219365
# exit taken: 0 with confidence: 0.7235177709299201
# exit taken: 0 with confidence: 0.7047421875241029
# exit taken: 0 with confidence: 0.7070399506026465
# exit taken: 0 with confidence: 0.7000583825598312
# exit taken: 0 with confidence: 0.720450371713862
# exit taken: 0 with confidence: 0.721312979861275
# exit taken: 0 with confidence: 0.7065467574339731
# exit taken: 0 with confidence: 0.7156951531708794
# exit taken: 0 with confidence: 0.7067214993303903
# exit taken: 0 with confidence: 0.7161700143270793
# exit taken: 0 with confidence: 0.7232241475876581
# Evaluating:  51%|█████▏    | 513/1000 [00:01<00:01, 282.47image/s]
# exit taken: 0 with confidence: 0.7201686273291181
# exit taken: 0 with confidence: 0.7203548083677241
# exit taken: 0 with confidence: 0.7005093924861531
# exit taken: 0 with confidence: 0.7248751691998054
# exit taken: 0 with confidence: 0.7231113097387467
# exit taken: 0 with confidence: 0.7236938199712718
# exit taken: 1 with confidence: 0.7133180488592975
# exit taken: 0 with confidence: 0.7228299447814197
# exit taken: 0 with confidence: 0.721359284753732
# exit taken: 0 with confidence: 0.713346825170498
# exit taken: 0 with confidence: 0.714375443937547
# exit taken: 0 with confidence: 0.7257283123757791
# exit taken: 0 with confidence: 0.7130387752622246
# exit taken: 0 with confidence: 0.7087961817213255
# exit taken: 0 with confidence: 0.7172891284397382
# exit taken: 0 with confidence: 0.7049428385613169
# exit taken: 0 with confidence: 0.7209706448072661
# exit taken: 0 with confidence: 0.7199409558936133
# exit taken: 0 with confidence: 0.7260177002984052
# Evaluating:  57%|█████▋    | 574/1000 [00:02<00:01, 289.68image/s]
# exit taken: 0 with confidence: 0.7243990950287028
# exit taken: 0 with confidence: 0.711040446323467
# exit taken: 2 with confidence: 0.7008986755642885
# exit taken: 0 with confidence: 0.7159908183210653
# exit taken: 0 with confidence: 0.707896982122014
# exit taken: 0 with confidence: 0.7180468624199088
# exit taken: 2 with confidence: 0.7031717644050993
# exit taken: 0 with confidence: 0.7137148448929526
# exit taken: 0 with confidence: 0.7216831154030301
# exit taken: 0 with confidence: 0.7043632873604996
# exit taken: 0 with confidence: 0.715794949218565
# exit taken: 0 with confidence: 0.7206556028178467
# exit taken: 0 with confidence: 0.710671745805829
# exit taken: 0 with confidence: 0.7004485983590805
# exit taken: 0 with confidence: 0.7253429248409748
# exit taken: 2 with confidence: 0.7179059991671687
# exit taken: 0 with confidence: 0.7089041010520943
# Evaluating:  63%|██████▎   | 632/1000 [00:02<00:01, 274.11image/s]
# exit taken: 0 with confidence: 0.7148884646600333
# exit taken: 0 with confidence: 0.7197750232835979
# exit taken: 0 with confidence: 0.7039644469680117
# exit taken: 0 with confidence: 0.7165033550043466
# exit taken: 0 with confidence: 0.7180306602891662
# exit taken: 0 with confidence: 0.7253135811213666
# exit taken: 0 with confidence: 0.7153517138463589
# exit taken: 0 with confidence: 0.7173346947859003
# exit taken: 0 with confidence: 0.7126587784472611
# exit taken: 0 with confidence: 0.7129923627674076
# exit taken: 0 with confidence: 0.707674894976401
# exit taken: 0 with confidence: 0.7154084702376295
# Evaluating:  69%|██████▉   | 691/1000 [00:02<00:01, 282.27image/s]
# exit taken: 0 with confidence: 0.7072814197468033
# exit taken: 1 with confidence: 0.7075287457869923
# exit taken: 0 with confidence: 0.7185568593815772
# exit taken: 0 with confidence: 0.7150937355939615
# exit taken: 0 with confidence: 0.7203860562249521
# exit taken: 0 with confidence: 0.7185976276713859
# exit taken: 0 with confidence: 0.7208759328685106
# exit taken: 0 with confidence: 0.7072608628432621
# exit taken: 0 with confidence: 0.7116980325131664
# exit taken: 0 with confidence: 0.7205109212622007
# exit taken: 0 with confidence: 0.7129741604602009
# exit taken: 0 with confidence: 0.7246243616247778
# exit taken: 0 with confidence: 0.7226750990033619
# exit taken: 0 with confidence: 0.7084750807162178
# Evaluating:  75%|███████▌  | 752/1000 [00:02<00:00, 283.41image/s]
# exit taken: 0 with confidence: 0.7160767749989735
# exit taken: 0 with confidence: 0.7230007559453508
# exit taken: 0 with confidence: 0.7225086211460843
# exit taken: 0 with confidence: 0.7189379942257275
# exit taken: 0 with confidence: 0.719214062042488
# exit taken: 0 with confidence: 0.7173511870428403
# exit taken: 0 with confidence: 0.7208916036911069
# exit taken: 0 with confidence: 0.7158108614270439
# exit taken: 0 with confidence: 0.7036745676563497
# exit taken: 0 with confidence: 0.7192429458671409
# exit taken: 0 with confidence: 0.7220108813567566
# exit taken: 0 with confidence: 0.7003545052492656
# exit taken: 0 with confidence: 0.7156869977172428
# exit taken: 0 with confidence: 0.7228103448287171
# exit taken: 0 with confidence: 0.7178645705664861
# exit taken: 0 with confidence: 0.7041586344615136
# exit taken: 0 with confidence: 0.706988851029439
# exit taken: 0 with confidence: 0.7180184136614461
# exit taken: 0 with confidence: 0.7137347377493666
# exit taken: 1 with confidence: 0.7135078347302194
# Evaluating:  81%|████████  | 810/1000 [00:02<00:00, 270.45image/s]
# exit taken: 0 with confidence: 0.7189191185059333
# exit taken: 0 with confidence: 0.7082246746041897
# exit taken: 0 with confidence: 0.7050576450661042
# exit taken: 0 with confidence: 0.7047802278903831
# exit taken: 0 with confidence: 0.7134635025421918
# exit taken: 0 with confidence: 0.7065928078799681
# exit taken: 0 with confidence: 0.7118431661160867
# exit taken: 0 with confidence: 0.7172881259769308
# exit taken: 0 with confidence: 0.7164364530232934
# exit taken: 0 with confidence: 0.7197149609825213
# exit taken: 0 with confidence: 0.7238968188915991
# exit taken: 0 with confidence: 0.714274788082189
# exit taken: 0 with confidence: 0.7238968188915991
# exit taken: 2 with confidence: 0.7027962508389045
# exit taken: 0 with confidence: 0.7114745526822148
# Evaluating:  87%|████████▋ | 872/1000 [00:03<00:00, 284.78image/s]
# exit taken: 0 with confidence: 0.7213381176455356
# exit taken: 0 with confidence: 0.7157599491091171
# exit taken: 0 with confidence: 0.7096217770133557
# exit taken: 0 with confidence: 0.7161161599987116
# exit taken: 0 with confidence: 0.7254327468285265
# exit taken: 2 with confidence: 0.7031720225507011
# exit taken: 0 with confidence: 0.7194433810495882
# exit taken: 2 with confidence: 0.7128911614884417
# exit taken: 0 with confidence: 0.7134823534002726
# exit taken: 0 with confidence: 0.7257075070565241
# exit taken: 0 with confidence: 0.7211831602938225
# exit taken: 0 with confidence: 0.7166409937163163
# exit taken: 0 with confidence: 0.7072659780457483
# exit taken: 0 with confidence: 0.7177791417991979
# exit taken: 0 with confidence: 0.7185269034184961
# exit taken: 0 with confidence: 0.7221214855182521
# exit taken: 0 with confidence: 0.7089765978413601
# exit taken: 0 with confidence: 0.7186967191096244
# exit taken: 0 with confidence: 0.706975665336567
# exit taken: 0 with confidence: 0.7019761555206072
# exit taken: 2 with confidence: 0.7033148053872519
# exit taken: 1 with confidence: 0.7027709568084638
# Evaluating:  95%|█████████▌| 953/1000 [00:03<00:00, 343.43image/s]
# exit taken: 0 with confidence: 0.717097454220112
# exit taken: 0 with confidence: 0.7150562166611553
# exit taken: 0 with confidence: 0.7214257774831936
# exit taken: 2 with confidence: 0.7015877744445026
# exit taken: 0 with confidence: 0.7155322660220467
# exit taken: 2 with confidence: 0.7065247560278913
# exit taken: 0 with confidence: 0.7277376850630499
# exit taken: 0 with confidence: 0.7205309866382494
# exit taken: 0 with confidence: 0.7203618905571271
# exit taken: 0 with confidence: 0.7235249624860003
# exit taken: 0 with confidence: 0.7200719027706609
# exit taken: 0 with confidence: 0.721150161264646
# exit taken: 0 with confidence: 0.7068290705352718
# exit taken: 0 with confidence: 0.7020557025156294
# exit taken: 0 with confidence: 0.7218642059855964
# exit taken: 0 with confidence: 0.728548905025154
# exit taken: 0 with confidence: 0.7203760838723856
# exit taken: 0 with confidence: 0.7195168548812609
# exit taken: 0 with confidence: 0.7142362007494107
# exit taken: 0 with confidence: 0.7198921848856334
# exit taken: 0 with confidence: 0.7241730609698204
# exit taken: 0 with confidence: 0.7164565989349919
# exit taken: 0 with confidence: 0.706345694209559
# exit taken: 0 with confidence: 0.7006719391967666
# exit taken: 0 with confidence: 0.7047447114413248
# exit taken: 0 with confidence: 0.7087347861660037
# exit taken: 0 with confidence: 0.7175854600071212
# exit taken: 0 with confidence: 0.7079685566002399
# exit taken: 0 with confidence: 0.7222922677677635
# Evaluating: 100%|██████████| 1000/1000 [00:03<00:00, 290.60image/s]
# exit taken: 0 with confidence: 0.7197250285225215
# exit taken: 0 with confidence: 0.7239832980602182
# exit taken: 1 with confidence: 0.7072996034903379
# exit taken: 0 with confidence: 0.7003933380604199
# exit taken: 0 with confidence: 0.721026648440381
# exit taken: 0 with confidence: 0.7196451449320304
# exit taken: 0 with confidence: 0.7212930672384149
# exit taken: 0 with confidence: 0.7049352061866598
# exit taken: 1 with confidence: 0.7064711195050075
# exit taken: 0 with confidence: 0.7221446525732005
# Number of correct: 295, wrong: 17
#
# Total # of Images: 312 TFLite model overall test accuracy with multi-exit: 0.9455
# Exit 1: taken 283 times, average confidence = 0.7159
# Exit 2: taken 11 times, average confidence = 0.7060
# Exit 3: taken 18 times, average confidence = 0.7073

# %% [markdown]
# # Convert .tflite to C arrays

# %%
import binascii

def convert_to_c_array(bytes) -> str:
  hexstr = binascii.hexlify(bytes).decode("UTF-8")
  hexstr = hexstr.upper()
  array = ["0x" + hexstr[i:i + 2] for i in range(0, len(hexstr), 2)]
  array = [array[i:i+10] for i in range(0, len(array), 10)]
  return ",\n  ".join([", ".join(e) for e in array])

def save_c_array_to_file(tflite_file_path):
  tflite_binary = open(tflite_file_path, 'rb').read()
  ascii_bytes = convert_to_c_array(tflite_binary)
  c_file = "const unsigned char tf_model[] DATA_ALIGN_ATTRIBUTE = {\n  " + ascii_bytes + "\n};\nconst int tf_model_len = " + str(len(tflite_binary)) + ";"
  # print(c_file)
  print(f"c_array_len: {len(c_file)}")
  # open("model.h", "w").write(c_file)
  open(tflite_file_path.split(".")[0]+".cpp", "w").write(c_file)

# %%
save_c_array_to_file("final_result/k_4_c_2_model_chunk_0.tflite")
save_c_array_to_file("final_result/k_4_c_2_model_chunk_1.tflite")
# save_c_array_to_file("final_result/k_4_c_3_model_chunk_2.tflite")
# Out:
# c_array_len: 148493
# c_array_len: 271873
